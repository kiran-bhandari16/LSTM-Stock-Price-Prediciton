# %% [markdown]
# <a href="https://colab.research.google.com/github/kiran-bhandari16/LSTM-Stock-Price-Prediciton/blob/main/Copy_of_Predicting_next(X)days_Stock_Price_Using_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
plt.style.use('ggplot')

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense, Dropout
import sklearn.metrics as metrics
from sklearn.metrics import mean_squared_error

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-072ddad9-901e-432e-83c4-4dffd3433f67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-072ddad9-901e-432e-83c4-4dffd3433f67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving updated-sbl-data.csv to updated-sbl-data.csv

# %%
df = pd.read_csv('updated-sbl-data.csv')
df.head()
# Out:
#          Date    Open    High     Low     Ltp       Turnover
# 0  2022-06-29  318.90  318.90  310.00  315.00   6,127,716.20
# 1  2022-06-28  312.00  316.50  306.00  313.00   5,707,986.70
# 2  2022-06-27  322.00  325.00  310.00  312.00  11,125,995.50
# 3  2022-06-26  312.90  320.00  308.00  320.00  28,577,745.10
# 4  2022-06-24  305.00  310.00  298.20  307.00  25,399,389.80

# %%
df = df.set_index("Date")[['Ltp']].head(1000)

# print('done')

# df.index

# %%
df = df.set_index(pd.to_datetime(df.index))

df.head()
# Out:
#                Ltp
# Date
# 2022-06-29  315.00
# 2022-06-28  313.00
# 2022-06-27  312.00
# 2022-06-26  320.00
# 2022-06-24  307.00

# %%
df.index
# Out:
# DatetimeIndex(['2022-06-29', '2022-06-28', '2022-06-27', '2022-06-26',
#                '2022-06-24', '2022-06-23', '2022-06-22', '2022-06-21',
#                '2022-06-20', '2022-06-19',
#                ...
#                '2018-03-04', '2018-02-28', '2018-02-27', '2018-02-26',
#                '2018-02-25', '2018-02-22', '2018-02-21', '2018-02-20',
#                '2018-02-18', '2018-02-15'],
#               dtype='datetime64[ns]', name='Date', length=1000, freq=None)

# %%
df.columns
# Out:
# Index(['Ltp'], dtype='object')

# %%
df["Ltp"] = df["Ltp"].str.replace(",","")
ltp = df["Ltp"].apply(lambda x: float(x))

# %%
scaler=MinMaxScaler()
df=pd.DataFrame(scaler.fit_transform(df),columns=df.columns, index=df.index)
df.head()
# Out:
#                  Ltp
# Date
# 2022-06-29  0.154172
# 2022-06-28  0.148126
# 2022-06-27  0.145103
# 2022-06-26  0.169287
# 2022-06-24  0.129988

# %%
df.plot(figsize=(14,8))
plt.title('last Trading prices')
plt.ylabel('normalized prices')
plt.show()

# %%
def split_sequences(seq, n_steps_in, n_steps_out):
    X,y =[], []
    
    for i in range(len(seq)):
        end = i+n_steps_in
        out_end = end+ n_steps_out
        
        if out_end >len(seq):
            break
            
        seq_x, seq_y = seq[i:end], seq[end:out_end]
        
        X.append(seq_x)
        y.append(seq_y)
    
    return np.array(X), np.array(y)

# %%
n_per_in = 50
n_per_out = 2

n_features = 1

X,y = split_sequences(list(df.Ltp), n_per_in,n_per_out)

print(X.shape)

X = X.reshape(X.shape[0],X.shape[1],n_features)

print(X.shape)
print(y.shape)
# Out:
# (949, 50)
# (949, 50, 1)
# (949, 2)

# %%
model = Sequential()
model.add(LSTM(50, activation='softsign', return_sequences=True, input_shape=(n_per_in,n_features)))
model.add(LSTM(n_features, activation='softsign', return_sequences=True))
model.add(LSTM(n_features, activation='softsign', return_sequences=True))
model.add(LSTM(n_features, activation='softsign', return_sequences=True))
model.add(LSTM(n_features, activation='softsign', return_sequences=True))
model.add(LSTM(n_features, activation='softsign'))
model.add(Dense(n_per_out))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 50, 50)            10400
#
#  lstm_1 (LSTM)               (None, 50, 1)             208
#
#  lstm_2 (LSTM)               (None, 50, 1)             12
#
#  lstm_3 (LSTM)               (None, 50, 1)             12
#
#  lstm_4 (LSTM)               (None, 50, 1)             12
#
#  lstm_5 (LSTM)               (None, 1)                 12
#
#  dense (Dense)               (None, 2)                 4
#
# ...
# Total params: 10,660
# Trainable params: 10,660
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mse', metrics=['mse'])

# %%
res = model.fit(X,y, epochs=500, batch_size=64, validation_split=0.1)
# Out:
# Epoch 1/500
# 14/14 [==============================] - 22s 566ms/step - loss: 0.1420 - mse: 0.1420 - val_loss: 0.0249 - val_mse: 0.0249
# Epoch 2/500
# 14/14 [==============================] - 3s 209ms/step - loss: 0.1281 - mse: 0.1281 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 3/500
# 14/14 [==============================] - 3s 243ms/step - loss: 0.1153 - mse: 0.1153 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 4/500
# 14/14 [==============================] - 2s 153ms/step - loss: 0.1032 - mse: 0.1032 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 5/500
# 14/14 [==============================] - 2s 119ms/step - loss: 0.0926 - mse: 0.0926 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 6/500
# 14/14 [==============================] - 2s 118ms/step - loss: 0.0834 - mse: 0.0834 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 7/500
# 14/14 [==============================] - 2s 119ms/step - loss: 0.0754 - mse: 0.0754 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 8/500
# ...

# %%
loss = res.history['loss']
val_loss = res.history['val_loss']
epochs=range(1,len(loss)+1)
plt.plot(epochs, loss,'y', label="Training loss")
plt.plot(epochs, val_loss, 'r', label='validation loss')
plt.title("Training and validation loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()


mse = res.history['mse']
val_mse = res.history['val_mse']
plt.plot(epochs, mse,'y', label="Training MSE")
plt.plot(epochs, val_mse, 'r', label='validation MSE')
plt.title("Training and validation MSE")
plt.xlabel('epochs')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,4))

y_predicts = model.predict(X[-1].reshape(1,n_per_in, n_features)).tolist()[0]

y_predicts = scaler.inverse_transform(np.array(y_predicts).reshape(-1,1)).tolist()

actual_value = scaler.inverse_transform(y[-1].reshape(-1,1)).tolist()

print("Predicted: ", y_predicts)
plt.plot(y_predicts, label="predicted value")

print("Actual Value: ",actual_value)
plt.plot(actual_value, label="Actual Value")

plt.title("Predicted Value vs Actual Value")
plt.ylabel("Price")
plt.legend()
plt.show()
# Out:
# Predicted:  [[297.5635282576084], [297.39994930028917]]
# Actual Value:  [[365.0], [364.0]]
